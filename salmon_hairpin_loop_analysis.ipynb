# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tabulate import tabulate

# %% [markdown]
# # first checking terminal to mid-sequence distance

# %%
simulation=7
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_terminal_all_dist.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.iloc[:,2:].copy()
#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon.iloc[:,2:].columns:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ordered_labels=[]
for residue_pair in labels:
    first=int(residue_pair.split(':')[1])
    second=int(residue_pair.split(':')[2])
    if second-first>=0:
        ordered_labels.append(residue_pair)
    elif second-first<0:
        ordered_labels.append(':'+str(second)+':'+str(first))
labels=ordered_labels
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=10,linewidth = 1, color='black',linestyle='dashed',label='10')
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (-1.6797435269780792, 91.5565442344711)

# %%
simulation=6
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_terminal_all_dist.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.iloc[:,2:].copy()
#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon.iloc[:,2:].columns:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ordered_labels=[]
for residue_pair in labels:
    first=int(residue_pair.split(':')[1])
    second=int(residue_pair.split(':')[2])
    if second-first>=0:
        ordered_labels.append(residue_pair)
    elif second-first<0:
        ordered_labels.append(':'+str(second)+':'+str(first))
labels=ordered_labels
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=10,linewidth = 1, color='black',linestyle='dashed',label='10')
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (-0.7474291806109137, 81.04930391270305)

# %%
simulation=12
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_terminal_all_dist.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.iloc[:,2:].copy()
#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon.iloc[:,2:].columns:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ordered_labels=[]
for residue_pair in labels:
    first=int(residue_pair.split(':')[1])
    second=int(residue_pair.split(':')[2])
    if second-first>=0:
        ordered_labels.append(residue_pair)
    elif second-first<0:
        ordered_labels.append(':'+str(second)+':'+str(first))
labels=ordered_labels
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=10,linewidth = 1, color='black',linestyle='dashed',label='10')
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (0.0265553958444964, 65.84799459270498)

# %% [markdown]
# # NEXT checking pairwise residues between all residues involved in hairpin loop (identified from previous section)

# %% [markdown]
# # ordered by increasing distance between residue indices, with at least 9 residues between them (i.e. less than 9 (or as indicated) were dropped from diagram) and MEAN less than the cutoff shown with dotted lines

# %%
simulation=5
distance_cutoff=11
cutoff_diff_between_residue_pair_indices=9
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=11,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=11)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(18, 9))
temp_salmon=pd.read_csv("salmon_sim5_trajectory_pairwise_res_hairpin.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
for residue_pair in temp_salmon.iloc[:,2:].columns:
    first=int(residue_pair.split(':')[1])
    second=int(residue_pair.split(':')[2])
    if abs(second-first)==1:
        temp_salmon.drop(residue_pair,axis=1,inplace=True)

temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].mean().sort_values()<distance_cutoff].index        
temp_salmon_onlydis_diff=[]
temp_salmon_onlydis_mindiff=[]
for residue_pair in temp_salmon_onlydis:
    first=int(residue_pair.split(':')[1])
    second=int(residue_pair.split(':')[2])
    temp_salmon_onlydis_diff.append([abs(first-second),':'+str(first)+':'+str(second)])
temp_salmon_onlydis_diff=sorted(temp_salmon_onlydis_diff,key=lambda x:x[0])
temp_salmon_onlydis_diff=[pair for pair in temp_salmon_onlydis_diff if pair[0]>=cutoff_diff_between_residue_pair_indices]
for residue_pair in temp_salmon_onlydis_diff:
    temp_salmon_onlydis_mindiff.append(residue_pair[1])
temp_salmon_onlydis=temp_salmon_onlydis_mindiff

#temp_salmon_onlydis=temp_salmon.iloc[:,2:].copy()
#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))

ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
#plt.axhline(y=10,linewidth = 1, color='black',linestyle='dashed',label='10')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=11)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (1.1880654150445107, 32.2047486538906)

# %%
simulation=6
distance_cutoff=11
cutoff_diff_between_residue_pair_indices=9
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=11,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=11)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(18, 9))
temp_salmon=pd.read_csv("salmon_sim6_trajectory_pairwise_res_hairpin.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
for residue_pair in temp_salmon.iloc[:,2:].columns:
    first=int(residue_pair.split(':')[1])
    second=int(residue_pair.split(':')[2])
    if abs(second-first)==1:
        temp_salmon.drop(residue_pair,axis=1,inplace=True)

temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].mean().sort_values()<distance_cutoff].index        
temp_salmon_onlydis_diff=[]
temp_salmon_onlydis_mindiff=[]
for residue_pair in temp_salmon_onlydis:
    first=int(residue_pair.split(':')[1])
    second=int(residue_pair.split(':')[2])
    temp_salmon_onlydis_diff.append([abs(first-second),':'+str(first)+':'+str(second)])
temp_salmon_onlydis_diff=sorted(temp_salmon_onlydis_diff,key=lambda x:x[0])
temp_salmon_onlydis_diff=[pair for pair in temp_salmon_onlydis_diff if pair[0]>=cutoff_diff_between_residue_pair_indices]
for residue_pair in temp_salmon_onlydis_diff:
    temp_salmon_onlydis_mindiff.append(residue_pair[1])
temp_salmon_onlydis=temp_salmon_onlydis_mindiff

#temp_salmon_onlydis=temp_salmon.iloc[:,2:].copy()
#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))

ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
#plt.axhline(y=10,linewidth = 1, color='black',linestyle='dashed',label='10')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=11)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (2.908631632331796, 16.009319567023717)

# %%
simulation=12
distance_cutoff=11
cutoff_diff_between_residue_pair_indices=4
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=11,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=11)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(18, 9))
temp_salmon=pd.read_csv("salmon_sim12_trajectory_pairwise_res_hairpin.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
for residue_pair in temp_salmon.iloc[:,2:].columns:
    first=int(residue_pair.split(':')[1])
    second=int(residue_pair.split(':')[2])
    if abs(second-first)==1:
        temp_salmon.drop(residue_pair,axis=1,inplace=True)

temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].mean().sort_values()<distance_cutoff].index        
temp_salmon_onlydis_diff=[]
temp_salmon_onlydis_mindiff=[]
for residue_pair in temp_salmon_onlydis:
    first=int(residue_pair.split(':')[1])
    second=int(residue_pair.split(':')[2])
    temp_salmon_onlydis_diff.append([abs(first-second),':'+str(first)+':'+str(second)])
temp_salmon_onlydis_diff=sorted(temp_salmon_onlydis_diff,key=lambda x:x[0])
temp_salmon_onlydis_diff=[pair for pair in temp_salmon_onlydis_diff if pair[0]>=cutoff_diff_between_residue_pair_indices]
for residue_pair in temp_salmon_onlydis_diff:
    temp_salmon_onlydis_mindiff.append(residue_pair[1])
temp_salmon_onlydis=temp_salmon_onlydis_mindiff

#temp_salmon_onlydis=temp_salmon.iloc[:,2:].copy()
#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))

ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
#plt.axhline(y=10,linewidth = 1, color='black',linestyle='dashed',label='10')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=11)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (2.40005216886059, 18.545811811480014)

# %% [markdown]
# # atom analysis for simulation 5

# %%
simulation=5
distance_cutoff=4
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim5_trajectory_pairwise_atom_res13-31.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (0.53046800929704, 22.70925055145783)

# %%
simulation=5
distance_cutoff=4
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim5_trajectory_pairwise_atom_res16-26.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (1.1270412314499956, 11.090539799188695)

# %%
simulation=5
distance_cutoff=5
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim5_trajectory_pairwise_atom_res12-30.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (0.635005695479969, 27.89880259497336)

# %%
simulation=5
distance_cutoff=4
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim5_trajectory_pairwise_atom_res10-32.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (-0.07811583153567336, 35.89542152953684)

# %%
simulation=5
distance_cutoff=5.5
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim5_trajectory_pairwise_atom_res16-28.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (0.7465714361107215, 19.487422233564313)

# %% [markdown]
# # atom analysis for simulation 6

# %%
simulation=6
distance_cutoff=4
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim6_trajectory_pairwise_atom_res21-30.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (1.17683668264395, 9.770824396007555)

# %%
simulation=6
distance_cutoff=4
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim6_trajectory_pairwise_atom_res19-32.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (1.240512059258771, 15.585361271692307)

# %%
simulation=6
distance_cutoff=4
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim6_trajectory_pairwise_atom_res19-33.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (1.3077281215917451, 12.308732365276363)

# %%
simulation=6
distance_cutoff=4
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim6_trajectory_pairwise_atom_res33-17.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (0.9473631610964168, 14.180959070493172)

# %%
simulation=6
distance_cutoff=4
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim6_trajectory_pairwise_atom_res20-32.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (1.0437579047765349, 12.396634352266089)

# %% [markdown]
# # atom analysis for simulation 12

# %%
simulation=12
distance_cutoff=4.5
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim12_trajectory_pairwise_atom_res10-14.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (1.402582649157099, 11.853082944437556)

# %%
simulation=12
distance_cutoff=5.5
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim12_trajectory_pairwise_atom_res16-4.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (2.066967612100311, 10.722466018107575)

# %%
simulation=12
distance_cutoff=5
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim12_trajectory_pairwise_atom_res4-10.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (1.355445604327086, 14.784811087270931)

# %%
simulation=12
distance_cutoff=4
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim12_trajectory_pairwise_atom_res4-15.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (1.1721611678526944, 10.718492137582684)

# %%
simulation=12
distance_cutoff=7
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels,fontsize=10,rotation=90)
    plt.setp(ax.get_yticklabels(), fontsize=10)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Residue Pair', fontsize=15)
data = []
labels=[]
fig,ax = plt.subplots(figsize=(15, 7))
temp_salmon=pd.read_csv("salmon_sim12_trajectory_pairwise_atom_res8-15.csv")
blank_df = pd.DataFrame()
for sim in temp_salmon.sim.unique():
    temp_df = temp_salmon[temp_salmon.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
temp_salmon = blank_df.copy()
del temp_df
del blank_df
temp_salmon=temp_salmon[temp_salmon.sim!=2]
temp_salmon=temp_salmon[temp_salmon.sim!=11]
salmon_sequence='MPRRRRSSSRPVRRRRRPRVSRRRRRRGGRRRR'
temp_salmon_onlydis=temp_salmon.copy()
temp_salmon_onlydis=temp_salmon.iloc[:,
                                     2:].mean().sort_values()[temp_salmon.iloc[:,
                                                                               2:].median().sort_values()<distance_cutoff].index        

#temp_salmon_onlydis=temp_salmon_onlydis.reindex(temp_salmon_onlydis.mean().sort_values().index,axis=1)
#temp_salmon=pd.concat([temp_salmon.iloc[:,:3],temp_salmon_onlydis],axis=1)
for pair in temp_salmon_onlydis:
    data.append(list(temp_salmon[temp_salmon.sim==simulation][pair].values))
    labels.append(str(pair))
ax.set_title('Salmon: Distance for '+'simulation '+str(simulation),
             fontsize=16)
ax.set_ylabel('Distance'+' ('+r'$\AA$'+')',fontsize=15)
#ax.set_ylim(11,37)
#ax.violinplot(data)
parts = ax.violinplot(data, showmeans=False, showmedians=True,
        showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#c2baff')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
parts['cmedians'].set_color('black')
parts['cbars'].set_color('black')
parts['cmins'].set_color('black')
parts['cmaxes'].set_color('black')
parts['cmedians'].set_linewidth(1)
parts['cbars'].set_linewidth(1)
parts['cmins'].set_linewidth(1)
parts['cmaxes'].set_linewidth(1)
set_axis_style(ax,labels)
#plt.axvline(x=1.5,linewidth = 1, color='black',linestyle='dashed')
plt.axhline(y=distance_cutoff,linewidth = 1, color='black',linestyle='dashed',label=str(distance_cutoff))
#ax.annotate('10 Angstrom',xy=(2,10),fontsize=20)
#plt.xticks(np.arange(0,20,10)+)
extraticks=[10]
lim = ax.get_ylim()
#ax.text(.145,.95,'salmon P1',fontsize=10,
#        horizontalalignment='center',
#        transform=ax.transAxes)
ax.set_yticks(list(ax.get_yticks()) + extraticks)
plt.setp(ax.get_yticklabels(),fontsize=10)
ax.set_ylim(lim)
#del temp_salmon, temp_salmon_onlydis
#fig.savefig('figures_for_publication/salmon_cys_tyr_pairwise_distance_all_sims.png',dpi=400,bbox_inches='tight')
# Out:
# (1.2907203554531537, 14.639505867206761)
